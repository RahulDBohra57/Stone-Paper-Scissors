# %%
import random

user = input("Enter your choice. 'r' is Rock, 'p' is Paper & 's' is Scissors:  ")
computer = random.choice(['r', 'p', 's'])

if user == computer:
    print("It's a tie")

elif (user == 'r' and computer == 's') or (user == 'p' and computer == 'r') or (user == 's' and computer == 'p'):
    print("You won!")

else:
    print("You lost!")

print(f'You chose {user} and computer chose {computer}')
# Out:
# Enter your choice. 'r' is Rock, 'p' is Paper & 's' is Scissors:   s
# You won!
# You chose s and computer chose p
